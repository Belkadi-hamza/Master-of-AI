# %% [markdown]
#
# ## Correction - Exercice 6 : Étude des points critiques

# %% [markdown]
# ## 🔹 Rappels mathématiques
#
# ### 1. Points critiques
# Les points critiques sont les solutions de :
# $$ f'(x) = 0 $$
#
# ### 2. Dérivée seconde
# - Si $f''(x) > 0$ → minimum local
# - Si $f''(x) < 0$ → maximum local
# - Si $f''(x) = 0$ → point de selle (ou test non concluant)
#
# ### 3. Fonction étudiée
# $$ f(x) = x^3 - 3x^2 + 2 $$

# %% [markdown]
# ## 🔹 1) Définition de la variable et de la fonction

# %%
import sympy as sp

# TODO 1: Définir la variable réelle x
x = ...

# TODO 2: Définir la fonction f(x) = x^3 - 3x^2 + 2
f = ...

# TODO 3: Afficher la fonction f
...

# %% [markdown]
# ## 🔹 2) Calcul de la dérivée première

# %%
# TODO 4: Calculer la dérivée première f'(x)
f_prime = ...

# TODO 5: Afficher f'(x)
...

# %% [markdown]
# ## 🔹 3) Résolution de f'(x) = 0

# %%
# TODO 4: Résoudre l'équation f'(x) = 0
critical_points = ...

# TODO 5: Afficher le message "Points critiques :"
...

# TODO 6: Afficher les points critiques
...

# %% [markdown]
# ## 🔹 4) Calcul de la dérivée seconde

# %%
# TODO 6: Calculer la dérivée seconde f''(x)
f_second = ...

# TODO 7: Afficher f''(x)
...

# TODO 8: Résoudre l'équation f'(x) = 0 (points critiques)
solutions = ...

# TODO 9: Afficher les solutions
...

# TODO 10: Étudier le signe de f'' pour déterminer la convexité
...

# %% [markdown]
# ## 🔹 5) Nature des points critiques

# %%
# TODO 1: Parcourir chaque point dans critical_points
for point in ...:

    # TODO 2: Calculer la valeur de la dérivée seconde au point
    value = ...

    # TODO 3: Afficher "Analyse au point x = ..."
    ...

    # TODO 4: Tester si la valeur est positive
    if ...:
        print("→ Minimum local")

    # TODO 5: Tester si la valeur est négative
    elif ...:
        print("→ Maximum local")

    # TODO 6: Sinon (valeur nulle)
    else:
        print("→ Point de selle ou test non concluant")
