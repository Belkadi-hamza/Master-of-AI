# %% [markdown]
#
# ## Correction - Exercice 5 : Fonctions convexes

# %% [markdown]
# ## 🔹 Rappels mathématiques
#
# ### 1. Fonction convexe
# Une fonction $f$ est convexe si :
# $$ f(\lambda x_1 + (1-\lambda)x_2) \leq \lambda f(x_1) + (1-\lambda)f(x_2) $$
#
# ### 2. Interprétation géométrique
# Le segment entre deux points du graphe est **au-dessus** de la courbe.
#
# ### 3. Fonctions données
# - $f(x) = x^2$
# - $g(x,y) = \log(e^x + e^y)$

# %% [markdown]
# ## 🔹 1) Tracer la courbe f(x) = x²

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO 1: Créer un vecteur x de 100 valeurs entre -5 et 5
x = ...

# TODO 2: Calculer f(x) = x^2
f = ...

# TODO 3: Créer une nouvelle figure
...

# TODO 4: Tracer la courbe de f en fonction de x
...

# TODO 5: Ajouter un titre "Courbe de f(x) = x²"
...

# TODO 6: Ajouter le label de l'axe x ("x")
...

# TODO 7: Ajouter le label de l'axe y ("f(x)")
...

# TODO 8: Afficher la grille
...

# TODO 9: Afficher la figure
...

# %% [markdown]
# ## 🔹 2) Points et segment (convexité)

# %%
# TODO 3: Définir deux points x1 = 2 et x2 = -3
x1, x2 = ..., ...

# TODO 4: Calculer y1 = f(x1) et y2 = f(x2)
y1, y2 = ..., ...

# TODO 5: Créer une nouvelle figure
...

# TODO 6: Tracer la courbe f(x)
...

# TODO 7: Ajouter les deux points (x1, y1) et (x2, y2) en rouge
...

# TODO 8: Tracer le segment reliant les deux points en vert
...

# TODO 9: Ajouter un titre "Illustration de la convexité"
...

# TODO 10: Afficher la grille
...

# TODO 11: Afficher la figure
...

# %% [markdown]
# ## 🔹 3) Fonction g(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# TODO 1: Définir la fonction g(x, y) = log(exp(x) + exp(y))
def g(x, y):
    return ...

# TODO 2: Créer un vecteur X et Y de 50 valeurs entre -4 et 4
X = ...
Y = ...

# TODO 3: Créer une grille avec meshgrid
X, Y = ...

# TODO 4: Calculer Z = g(X, Y)
Z = ...

# TODO 5: Créer une figure
fig = ...

# TODO 6: Ajouter un subplot 3D
ax = ...

# TODO 7: Tracer la surface 3D
...

# TODO 8: Définir deux points p1 = (2, 3, g(2,3)) et p2 = (1, -3, g(1,-3))
p1 = ...
p2 = ...

# TODO 9: Ajouter les deux points en rouge
...

# TODO 10: Tracer le segment reliant p1 et p2 en cyan
...

# TODO 11: Ajouter un titre "Surface de g et segment"
...

# TODO 12: Afficher la figure
...
