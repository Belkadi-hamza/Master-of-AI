# %%
import sympy as sp

# %% [markdown]
# # Create Symbolic Variables

# %%
x = sp.Symbol('x', negative=True, integer=True)
a, b = sp.symbols('a b')

# %% [markdown]
# # Algebraic Expressions

# %%
f = x**2 + a*x + b
f
# Out:
# a*x + b + x**2

# %% [markdown]
# ## Expand
